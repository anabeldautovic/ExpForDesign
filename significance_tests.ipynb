# %%
from significance_tests import compare_results

# %%
# Data from the provided table for Deezer (alpha_word, alpha_ent)
paper_results_deezer = {
    (20, 0.2, 0.3): 50.2, (50, 0.2, 0.3): 48.9, (100, 0.2, 0.3): 51.4, (200, 0.2, 0.3): 48.4,
    (20, 0.2, 0.4): 53.1, (50, 0.2, 0.4): 49.2, (100, 0.2, 0.4): 50.8, (200, 0.2, 0.4): 50.6,
    (20, 0.3, 0.3): 48.5, (50, 0.3, 0.3): 52.1, (100, 0.3, 0.3): 51.5, (200, 0.3, 0.3): 49.8,
    (20, 0.3, 0.4): 53.3, (50, 0.3, 0.4): 50.9, (100, 0.3, 0.4): 55.3, (200, 0.3, 0.4): 51.6,
    (20, 0.4, 0.3): 53.2, (50, 0.4, 0.3): 51.5, (100, 0.4, 0.3): 52.2, (200, 0.4, 0.3): 50.0,
    (20, 0.4, 0.4): 56.4, (50, 0.4, 0.4): 52.6, (100, 0.4, 0.4): 48.1, (200, 0.4, 0.4): 49.0,
    (20, 0.5, 0.3): 52.5, (50, 0.5, 0.3): 56.3, (100, 0.5, 0.3): 50.8, (200, 0.5, 0.3): 55.4,
    (20, 0.5, 0.4): 56.3, (50, 0.5, 0.4): 60.6, (100, 0.5, 0.4): 54.9, (200, 0.5, 0.4): 53.3
}

paper_results_itunes = {
    (20, 0.2, 0.3): 49.3, (50, 0.2, 0.3): 43.3, (100, 0.2, 0.3): 49.5, (200, 0.2, 0.3): 47.0,
    (20, 0.2, 0.4): 47.2, (50, 0.2, 0.4): 49.5, (100, 0.2, 0.4): 50.7, (200, 0.2, 0.4): 51.3,
    (20, 0.3, 0.3): 50.3, (50, 0.3, 0.3): 52.5, (100, 0.3, 0.3): 49.0, (200, 0.3, 0.3): 48.2,
    (20, 0.3, 0.4): 52.8, (50, 0.3, 0.4): 49.5, (100, 0.3, 0.4): 50.6, (200, 0.3, 0.4): 51.1,
    (20, 0.4, 0.3): 52.4, (50, 0.4, 0.3): 51.9, (100, 0.4, 0.3): 49.2, (200, 0.4, 0.3): 47.4,
    (20, 0.4, 0.4): 50.6, (50, 0.4, 0.4): 46.7, (100, 0.4, 0.4): 49.0, (200, 0.4, 0.4): 46.1,
    (20, 0.5, 0.3): 50.5, (50, 0.5, 0.3): 52.0, (100, 0.5, 0.3): 48.7, (200, 0.5, 0.3): 46.1
}

our_results_deezer = {
    (20, 0.2, 0.3): 51.6667, (50, 0.2, 0.3): 52.9939, (100, 0.2, 0.3): 52.2273, (200, 0.2, 0.3): 52.4843,
    (20, 0.2, 0.4): 49.3137, (50, 0.2, 0.4): 47.3993, (100, 0.2, 0.4): 47.3955, (200, 0.2, 0.4): 47.9509,
    (20, 0.3, 0.3): 52.286599, (50, 0.3, 0.3): 52.0317, (100, 0.3, 0.3): 50.048699, (200, 0.3, 0.3): 52.01,
    (20, 0.3, 0.4): 48.293, (50, 0.3, 0.4): 48.806, (100, 0.3, 0.4): 47.8685, (200, 0.3, 0.4): 47.8685,
    (20, 0.4, 0.3): 56.582, (50, 0.4, 0.3): 50.2945, (100, 0.4, 0.3): 55.1003999, (200, 0.4, 0.3): 49.7677,
    (20, 0.4, 0.4): 48.806, (50, 0.4, 0.4): 48.806, (100, 0.4, 0.4): 48.9441, (200, 0.4, 0.4): 48.9441,
    (20, 0.5, 0.3): 54.7855, (50, 0.5, 0.3): 50.3283999, (100, 0.5, 0.3): 50.6586, (200, 0.5, 0.3): 52.52469999,
    (20, 0.5, 0.4): 48.806, (50, 0.5, 0.4): 48.806, (100, 0.5, 0.4): 48.806, (200, 0.5, 0.4): 48.806
}

our_results_itunes = {
    (20, 0.2, 0.3): 49.9329, (50, 0.2, 0.3): 50.78, (100, 0.2, 0.3): 47.456, (200, 0.2, 0.3): 50.3251,
    (20, 0.2, 0.4): 49.8557, (50, 0.2, 0.4): 50.3039, (100, 0.2, 0.4): 51.7273, (200, 0.2, 0.4): 52.2752,
    (20, 0.3, 0.3): 51.9444, (50, 0.3, 0.3): 49.3462, (100, 0.3, 0.3): 50.1277, (200, 0.3, 0.3): 52.9196,
    (20, 0.3, 0.4): 46.533, (50, 0.3, 0.4): 50.7915, (100, 0.3, 0.4): 49.0608, (200, 0.3, 0.4): 49.1352,
    (20, 0.4, 0.3): 51.1992, (50, 0.4, 0.3): 56.6152, (100, 0.4, 0.3): 50.5984, (200, 0.4, 0.3): 50.0959,
    (20, 0.4, 0.4): 48.6064, (50, 0.4, 0.4): 48.7975, (100, 0.4, 0.4): 49.0353, (200, 0.4, 0.4): 47.331,
    (20, 0.5, 0.3): 47.8196, (50, 0.5, 0.3): 50.1709, (100, 0.5, 0.3): 55.8435, (200, 0.5, 0.3): 49.5443,
    (20, 0.5, 0.4): 47.331, (50, 0.5, 0.4): 47.331, (100, 0.5, 0.4): 47.331, (200, 0.5, 0.4): 47.331
}

# %%
print("Deezer Results Comparison:")
compare_results(paper_results_deezer, our_results)
# Out:
# Deezer Results Comparison:
# n_topics=20, alpha_word=0.2, alpha_ent=0.3
#   Paper Result: 51.6667
#   Our Result: 51.6667
#   Difference: 0.0000
#   The difference is negligible.
# n_topics=50, alpha_word=0.2, alpha_ent=0.3
#   Paper Result: 52.9939
#   Our Result: 52.9939
#   Difference: 0.0000
#   The difference is negligible.
# n_topics=100, alpha_word=0.2, alpha_ent=0.3
#   Paper Result: 52.2273
#   Our Result: 47.3955
#   Difference: -4.8318
#   The difference is noticeable.
# n_topics=200, alpha_word=0.2, alpha_ent=0.3
#   Paper Result: 52.4843
#   Our Result: 47.9509
#   Difference: -4.5334
#   The difference is noticeable.
# n_topics=20, alpha_word=0.2, alpha_ent=0.4
#   Paper Result: 49.3137
#   Our Result: 49.3137
#   Difference: 0.0000
#   The difference is negligible.
# n_topics=50, alpha_word=0.2, alpha_ent=0.4
#   Paper Result: 47.3993
#   Our Result: 47.3993
#   Difference: 0.0000
#   The difference is negligible.
# n_topics=100, alpha_word=0.2, alpha_ent=0.4
# ...
